# %%
# !unzip "/content/CarDetect.v1i.yolov8.zip"
# Out:
# Archive:  /content/CarDetect.v1i.yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/-0FB0E465-1451-4618-84CD-1A1A88293B08-png_jpg.rf.6ed689af20149113d913d1c9d81cab0b.jpg
#  extracting: test/images/-156F82DF-5099-4AEA-8574-19720B40C034-png_jpg.rf.5834f5f2f21fcfb9d2d5d45267cd4acb.jpg
#  extracting: test/images/-15F66BCC-7D1B-4C04-82EF-C560EC4C612E-png_jpg.rf.ac27e891aecf71173f63a81e815c392a.jpg
#  extracting: test/images/-3827C0BE-B55D-4ADE-9938-9DC7D50A32DD-png_jpg.rf.0e18f397d55bb9d21f45cdd3a8167f99.jpg
#  extracting: test/images/-410FB936-1128-4721-89DE-79E2F58D3B24-png_jpg.rf.51f355662d8bac817c8d941615cddad4.jpg
#  extracting: test/images/-41421EB3-10E7-4E8B-9D22-424751A9FE8A-png_jpg.rf.da368d775f84c07b92a94c80d98924da.jpg
#  extracting: test/images/-4B741C2C-6B83-4220-B69F-FCD31BA7BD93-png_jpg.rf.bb006222b3c42c0283598310d2e805dd.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics
# !cd ultralytics
# !pip install -e ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# Obtaining file:///content/ultralytics
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.202
#     Uninstalling ultralytics-8.0.202:
#       Successfully uninstalled ultralytics-8.0.202
#   Running setup.py develop for ultralytics
# ...

# %%
# !yolo detect train data="/content/data.yaml" model=yolov8s.pt epochs=15 imgsz=320
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect predict  model=yolov8n source="/content/train/images/-3130BF7E-8143-44C3-AC0D-8068C9108560-png_jpg.rf.35eac95f0a67153cfaff87cdc2a83d90.jpg"
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/train/images/-3130BF7E-8143-44C3-AC0D-8068C9108560-png_jpg.rf.35eac95f0a67153cfaff87cdc2a83d90.jpg: 640x640 (no detections), 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/ultralytics/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image

# %%
# !yolo detect predict  model=yolov8n source="/content/train/images/-152B35A7-2687-4126-B46B-5382319E7A3C-png_jpg.rf.ac125413ad58443e00376f16c5656ad7.jpg"
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/train/images/-152B35A7-2687-4126-B46B-5382319E7A3C-png_jpg.rf.ac125413ad58443e00376f16c5656ad7.jpg: 640x640 1 car, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/ultralytics/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
sample = "/content/train/images/-152B35A7-2687-4126-B46B-5382319E7A3C-png_jpg.rf.ac125413ad58443e00376f16c5656ad7.jpg"
Image(filename=sample)

# %%
detected = "/content/ultralytics/runs/detect/predict4/-152B35A7-2687-4126-B46B-5382319E7A3C-png_jpg.rf.ac125413ad58443e00376f16c5656ad7.jpg"
Image(filename=detected)
